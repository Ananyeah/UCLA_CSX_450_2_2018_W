# %%
titanic <- read.table('train.csv', sep=",", header = T)

# %%
rownames(titanic) <- titanic$PassengerId
titanic$PassengerId <- NULL
titanic$Name <- NULL

# %%
names(titanic)
# Out:
#  [1] "Survived" "Pclass"   "Sex"      "Age"      "SibSp"    "Parch"
#  [7] "Ticket"   "Fare"     "Cabin"    "Embarked"

# %%
str(titanic)
# Out:
# 'data.frame':	891 obs. of  10 variables:
#  $ Survived: int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Pclass  : int  3 1 3 1 3 3 1 3 3 2 ...
#  $ Sex     : Factor w/ 2 levels "female","male": 2 1 1 1 2 2 2 2 1 1 ...
#  $ Age     : num  22 38 26 35 35 NA 54 2 27 14 ...
#  $ SibSp   : int  1 1 0 1 0 0 0 3 0 1 ...
#  $ Parch   : int  0 0 0 0 0 0 0 1 2 0 ...
#  $ Ticket  : Factor w/ 681 levels "110152","110413",..: 524 597 670 50 473 276 86 396 345 133 ...
#  $ Fare    : num  7.25 71.28 7.92 53.1 8.05 ...
#  $ Cabin   : Factor w/ 148 levels "","A10","A14",..: 1 83 1 57 1 1 131 1 1 1 ...
#  $ Embarked: Factor w/ 4 levels "","C","Q","S": 4 2 4 4 4 3 4 4 4 2 ...

# %%
titanic$Sex <- as.integer(titanic$Sex == 'female')

# %%
titanic$Pclass <- factor(titanic$Pclass)
titanic$Embarked <- factor(titanic$Embarked)

# %%
titanic$Ticket <- NULL
titanic$Cabin <- NULL

# %%
str(titanic)
# Out:
# 'data.frame':	891 obs. of  8 variables:
#  $ Survived: int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Pclass  : Factor w/ 3 levels "1","2","3": 3 1 3 1 3 3 1 3 3 2 ...
#  $ Sex     : int  0 1 1 1 0 0 0 0 1 1 ...
#  $ Age     : num  22 38 26 35 35 NA 54 2 27 14 ...
#  $ SibSp   : int  1 1 0 1 0 0 0 3 0 1 ...
#  $ Parch   : int  0 0 0 0 0 0 0 1 2 0 ...
#  $ Fare    : num  7.25 71.28 7.92 53.1 8.05 ...
#  $ Embarked: Factor w/ 4 levels "","C","Q","S": 4 2 4 4 4 3 4 4 4 2 ...

# %%
colSums(is.na(titanic))
# Out:
# Survived   Pclass      Sex      Age    SibSp    Parch     Fare Embarked
#        0        0        0      177        0        0        0        0

# %%
attach(titanic)
titanic
# Out:
# The following objects are masked from titanic (pos = 3):
#
#     Age, Embarked, Fare, Parch, Pclass, Sex, SibSp, Survived
#     Survived Pclass Sex Age SibSp Parch Fare     Embarked
# 1   0        3      0   22  1     0       7.2500 S
# 2   1        1      1   38  1     0      71.2833 C
# 3   1        3      1   26  0     0       7.9250 S
# 4   1        1      1   35  1     0      53.1000 S
# 5   0        3      0   35  0     0       8.0500 S
# 6   0        3      0   NA  0     0       8.4583 Q
# 7   0        1      0   54  0     0      51.8625 S
# 8   0        3      0    2  3     1      21.0750 S
# 9   1        3      1   27  0     2      11.1333 S
# 10  1        2      1   14  1     0      30.0708 C
# 11  1        3      1    4  1     1      16.7000 S
# 12  1        1      1   58  0     0      26.5500 S
# 13  0        3      0   20  0     0       8.0500 S
# 14  0        3      0   39  1     5      31.2750 S
# 15  0        3      1   14  0     0       7.8542 S
# 16  1        2      1   55  0     0      16.0000 S
# 17  0        3      0    2  4     1      29.1250 Q
# 18  1        2      0   NA  0     0      13.0000 S
# 19  0        3      1   31  1     0      18.0000 S
# 20  1        3      1   NA  0     0       7.2250 C
# 21  0        2      0   35  0     0      26.0000 S
# 22  1        2      0   34  0     0      13.0000 S
# 23  1        3      1   15  0     0       8.0292 Q
# 24  1        1      0   28  0     0      35.5000 S
# 25  0        3      1    8  3     1      21.0750 S
# 26  1        3      1   38  1     5      31.3875 S
# 27  0        3      0   NA  0     0       7.2250 C
# 28  0        1      0   19  3     2     263.0000 S
# 29  1        3      1   NA  0     0       7.8792 Q
# 30  0        3      0   NA  0     0       7.8958 S
# ⋮   ⋮        ⋮      ⋮   ⋮   ⋮     ⋮     ⋮        ⋮
# 862 0        2      0   21  1     0     11.5000  S
# 863 1        1      1   48  0     0     25.9292  S
# 864 0        3      1   NA  8     2     69.5500  S
# 865 0        2      0   24  0     0     13.0000  S
# 866 1        2      1   42  0     0     13.0000  S
# 867 1        2      1   27  1     0     13.8583  C
# 868 0        1      0   31  0     0     50.4958  S
# 869 0        3      0   NA  0     0      9.5000  S
# 870 1        3      0    4  1     1     11.1333  S
# 871 0        3      0   26  0     0      7.8958  S
# 872 1        1      1   47  1     1     52.5542  S
# 873 0        1      0   33  0     0      5.0000  S
# 874 0        3      0   47  0     0      9.0000  S
# 875 1        2      1   28  1     0     24.0000  C
# 876 1        3      1   15  0     0      7.2250  C
# 877 0        3      0   20  0     0      9.8458  S
# 878 0        3      0   19  0     0      7.8958  S
# 879 0        3      0   NA  0     0      7.8958  S
# 880 1        1      1   56  0     1     83.1583  C
# 881 1        2      1   25  0     1     26.0000  S
# 882 0        3      0   33  0     0      7.8958  S
# 883 0        3      1   22  0     0     10.5167  S
# 884 0        2      0   28  0     0     10.5000  S
# 885 0        3      0   25  0     0      7.0500  S
# 886 0        3      1   39  0     5     29.1250  Q
# 887 0        2      0   27  0     0     13.0000  S
# 888 1        1      1   19  0     0     30.0000  S
# 889 0        3      1   NA  1     2     23.4500  S
# 890 1        1      0   26  0     0     30.0000  C
# 891 0        3      0   32  0     0      7.7500  Q

# %%
library(repr); options(repr.plot.width=10, repr.plot.height=3)
par(mfrow = c(1,6))
hist(Survived)
hist(Sex)
hist(Age)
hist(SibSp)
hist(Parch)
hist(Fare)
# Out:
# Plot with title “Histogram of Fare”

# %%
library(MASS)
par(mfrow = c(1,6))
truehist(Survived)
truehist(Sex)
truehist(Age)
truehist(SibSp)
truehist(Parch)
truehist(Fare)
# Out:
# plot without title

# %%
options(repr.plot.width = 5, repr.plot.height = 5)
pairs(titanic)
# Out:
# plot without title

# %%
titanic_numeric_features <- Filter(is.numeric, titanic)

# %%
cor(titanic_numeric_features)
pairs(titanic_numeric_features)
# Out:
#          Survived    Sex       Age SibSp      Parch      Fare
# Survived  1.00000000 0.5433514 NA  -0.0353225 0.08162941 0.2573065
# Sex       0.54335138 1.0000000 NA   0.1146308 0.24548896 0.1823328
# Age               NA        NA  1          NA         NA        NA
# SibSp    -0.03532250 0.1146308 NA   1.0000000 0.41483770 0.1596510
# Parch     0.08162941 0.2454890 NA   0.4148377 1.00000000 0.2162249
# Fare      0.25730652 0.1823328 NA   0.1596510 0.21622494 1.0000000
# plot without title

# %%
mean(titanic_numeric_features$Age, na.rm = T)
# Out:
# [1] 29.69912

# %%
mean_age <- mean(titanic_numeric_features$Age, na.rm = T)
titanic_numeric_features$Age[is.na(titanic_numeric_features$Age)] <- mean_age

# %%
cor(titanic_numeric_features)
# Out:
#          Survived    Sex         Age         SibSp      Parch       Fare
# Survived  1.00000000  0.54335138 -0.06980852 -0.0353225  0.08162941 0.25730652
# Sex       0.54335138  1.00000000 -0.08415344  0.1146308  0.24548896 0.18233283
# Age      -0.06980852 -0.08415344  1.00000000 -0.2326246 -0.17919092 0.09156609
# SibSp    -0.03532250  0.11463081 -0.23262459  1.0000000  0.41483770 0.15965104
# Parch     0.08162941  0.24548896 -0.17919092  0.4148377  1.00000000 0.21622494
# Fare      0.25730652  0.18233283  0.09156609  0.1596510  0.21622494 1.00000000
